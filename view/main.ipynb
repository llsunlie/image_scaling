# %%
from multi_evaluate import evaluate

# %%
ALGORITHM_NAME_LIST = [
    'bicubic',
    'bilinear',
    'cubicBSpline',
    'lagrange',
    'lanczos2',
    'lanczos3',
    'nearest',
    'newton',
    'shannon'
]

ALGORITHM_ARGS_MAP = {
    'lagrange': [3],
    'newton': [3],
    'shannon': [3]
}

# %%
evaluate(
    SRC_PATH = '../data/src/img1_160x90.png',
    ORIGINAL_IMG_PATH = '../data/src/img1_640x360.png',
    TARGET_DIR = '../data/target/',
    ALGORITHM_NAME_LIST = ALGORITHM_NAME_LIST,
    ALGORITHM_ARGS_MAP = ALGORITHM_ARGS_MAP,
    SHOW_LOG = False
)

# %%
evaluate(
    SRC_PATH = '../data/src/img1_160x90.png',
    ORIGINAL_IMG_PATH = '../data/src/img1_1280x720.png',
    TARGET_DIR = '../data/target/',
    ALGORITHM_NAME_LIST = ALGORITHM_NAME_LIST,
    ALGORITHM_ARGS_MAP = ALGORITHM_ARGS_MAP,
    SHOW_LOG = False
)

# %%
evaluate(
    SRC_PATH = '../data/src/img1_160x90.png',
    ORIGINAL_IMG_PATH = '../data/src/img1_1920x1080.png',
    TARGET_DIR = '../data/target/',
    ALGORITHM_NAME_LIST = ALGORITHM_NAME_LIST,
    ALGORITHM_ARGS_MAP = ALGORITHM_ARGS_MAP,
    SHOW_LOG = False
)
